# %%
# %load_ext autoreload
# %autoreload 2
import os; import sys; sys.path.append('../')
import pandas as pd
import tqdm
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

import socceraction.vaep as vaep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## Configure file and folder names
datafolder = "../data"
spadl_h5 = os.path.join(datafolder,"spadl.h5")
predictions_h5 = os.path.join(datafolder,"predictions.h5")

# %%
games = pd.read_hdf(spadl_h5,"games")
games = games[games.competition_name == "FIFA World Cup"]
print("nb of games:", len(games))
# Out:
# nb of games: 64

# %%
players = pd.read_hdf(spadl_h5,"players")
teams = pd.read_hdf(spadl_h5,"teams")
actiontypes = pd.read_hdf(spadl_h5, "actiontypes")
bodyparts = pd.read_hdf(spadl_h5, "bodyparts")
results = pd.read_hdf(spadl_h5, "results")

A = []
for game in tqdm.tqdm(list(games.itertuples())):
    actions = pd.read_hdf(spadl_h5,f"actions/game_{game.game_id}")
    actions = (
        actions.merge(actiontypes)
        .merge(results)
        .merge(bodyparts)
        .merge(players,"left",on="player_id")
        .merge(teams,"left",on="team_id")
        .sort_values(["period_id", "time_seconds", "timestamp"])
        .reset_index(drop=True)
    )
    preds = pd.read_hdf(predictions_h5,f"game_{game.game_id}")
    values = vaep.value(actions,preds.scores,preds.concedes)
    A.append(pd.concat([actions,preds,values],axis=1))
A = pd.concat(A).sort_values(["game_id","period_id", "time_seconds", "timestamp"]).reset_index(drop=True)
A.columns
# Out:
# 100%|██████████| 64/64 [00:06<00:00,  9.55it/s]
# Index(['game_id', 'period_id', 'time_seconds', 'timestamp', 'team_id',
#        'player_id', 'start_x', 'start_y', 'end_x', 'end_y', 'type_id',
#        'result_id', 'bodypart_id', 'type_name', 'result_name', 'bodypart_name',
#        'country_id', 'country_name', 'extra', 'jersey_number', 'player_name',
#        'player_nickname', 'team_name', 'scores', 'concedes', 'offensive_value',
#        'defensive_value', 'vaep_value'],
#       dtype='object')

# %% [markdown]
# ### Most valuable players in the world cup

# %%
A["player"] = A[["player_nickname","player_name"]].apply(lambda x: x[0] if x[0] else x[1],axis=1)

A["count"] = 1

A_ = A[A.type_name != "shot_penalty"] # ignore penalties
players = (
    A_[["player_id","team_name","player","vaep_value","count"]]
    .groupby(["player_id","team_name","player"])
    .sum()
    .reset_index()
)
players = players.sort_values("vaep_value",ascending=False)
players
# Out:
#      player_id     team_name                     player  vaep_value  count
# 6         3009        France              Kylian Mbappé    4.022927    495
# 50        3308       England            Kieran Trippier    3.787583    689
# 122       4320        Brazil                     Neymar    3.383777    749
# 92        3621       Belgium                Eden Hazard    3.328818    690
# 152       5186        Russia            Denis Cheryshev    3.194341    213
# 241       5463       Croatia                Luka Modrić    3.177810   1034
# 17        3089       Belgium            Kevin De Bruyne    3.129208    716
# 599      20004        France                 Paul Pogba    3.081210    676
# 248       5470       Croatia               Ivan Rakitić    2.989283    835
# 36        3244       England                John Stones    2.883331    937
# 352       5574       Germany                 Toni Kroos    2.778240    647
# 71        3501        Brazil          Philippe Coutinho    2.720943    703
# 281       5503     Argentina               Lionel Messi    2.704808    524
# 121       4319       Uruguay             Edinson Cavani    2.654940    226
# 593      10955       England                 Harry Kane    2.621982    324
# 525       6196      Colombia                 Yerry Mina    2.449056    325
# 172       5207      Portugal          Cristiano Ronaldo    2.441317    297
# 26        3176       Belgium             Thomas Meunier    2.276687    475
# 136       5170        Russia            Mário Fernandes    2.274088    450
# 252       5474       Croatia               Ivan Perišić    2.070561    454
# 263       5485        France             Raphaël Varane    2.001598    628
# 77        3533   Switzerland            Xherdan Shaqiri    1.949615    450
# 55        3336       England              Harry Maguire    1.933390    829
# 209       5246       Uruguay                Luis Suárez    1.844733    327
# 16        3083   South Korea              Son Heung-Min    1.810799    230
# 469       5692      Colombia     Juan Fernando Quintero    1.782824    374
# 251       5473       Nigeria                 Ahmed Musa    1.776397    162
# 464       5687         Japan               Takashi Inui    1.744770    296
# 451       5674       Senegal               Moussa Wagué    1.701559    168
# 254       5476        France            Benjamin Pavard    1.667134    615
# ..         ...           ...                        ...         ...    ...
# 154       5188  Saudi Arabia              Hattan Babhir   -0.359462    154
# 581       6351       Uruguay           Cristhian Stuani   -0.364225     53
# 259       5481     Australia              Mathew Leckie   -0.402390    219
# 598      19988        Sweden               Jimmy Durmaz   -0.404945     11
# 418       5641        Panama       Michael Amir Murillo   -0.406577    182
# 388       5610   South Korea                Kim Min-Woo   -0.421352    131
# 33        3233       England            Raheem Sterling   -0.429548    379
# 127       4447       Denmark         Martin Braithwaite   -0.429842    144
# 584       6354        Russia          Aleksandr Erokhin   -0.433998     42
# 11        3054        Brazil                Fernandinho   -0.440532    234
# 279       5501       Iceland  Hörður Björgvin Magnússon   -0.442710    175
# 340       5562       Germany              Thomas Müller   -0.451378    229
# 213       5250         Egypt                Ahmed Fathy   -0.467802    310
# 500       5832       Nigeria             Tyronne Ebuehi   -0.496021     55
# 233       5455       Nigeria       William Troost-Ekong   -0.543371    221
# 351       5573        Mexico              Héctor Moreno   -0.569933    272
# 345       5567        Mexico              Edson Álvarez   -0.620063    337
# 217       5254         Egypt                   Ali Gabr   -0.644969    164
# 445       5668        Poland         Robert Lewandowski   -0.658130    200
# 328       5550   Switzerland                Yann Sommer   -0.686567    211
# 439       5662        Poland              Thiago Cionek   -0.711555    155
# 215       5252         Egypt              Marwan Mohsen   -0.766923    125
# 257       5479     Australia                Aziz Behich   -0.832284    365
# 596      11098        Sweden                Marcus Berg   -0.927424    207
# 89        3604        France             Olivier Giroud   -0.944225    324
# 186       5223       Morocco            Aziz Bouhaddouz   -0.959839      9
# 30        3202        Brazil              Gabriel Jesus   -1.005869    273
# 117       4269        Serbia        Aleksandar Mitrović   -1.334005    171
# 343       5565       Germany                Mario Gómez   -1.335697     33
# 462       5685      Colombia             Carlos Sánchez   -1.377752    144
#
# [602 rows x 5 columns]

# %% [markdown]
# ### Normalize for minutes played

# %%
pg = pd.read_hdf(spadl_h5,"player_games")
pg = pg[pg.game_id.isin(games.game_id)]
mp = pg[["player_id","minutes_played"]].groupby("player_id").sum().reset_index()
stats = players.merge(mp)
stats = stats[stats.minutes_played > 150]
stats["vaep_rating"] = stats.vaep_value * 90 / stats.minutes_played
stats.sort_values("vaep_value",ascending=False)
# Out:
#      player_id     team_name                     player  vaep_value  count  \
# 0         3009        France              Kylian Mbappé    4.022927    495
# 1         3308       England            Kieran Trippier    3.787583    689
# 2         4320        Brazil                     Neymar    3.383777    749
# 3         3621       Belgium                Eden Hazard    3.328818    690
# 4         5186        Russia            Denis Cheryshev    3.194341    213
# 5         5463       Croatia                Luka Modrić    3.177810   1034
# 6         3089       Belgium            Kevin De Bruyne    3.129208    716
# 7        20004        France                 Paul Pogba    3.081210    676
# 8         5470       Croatia               Ivan Rakitić    2.989283    835
# 9         3244       England                John Stones    2.883331    937
# 10        5574       Germany                 Toni Kroos    2.778240    647
# 11        3501        Brazil          Philippe Coutinho    2.720943    703
# 12        5503     Argentina               Lionel Messi    2.704808    524
# 13        4319       Uruguay             Edinson Cavani    2.654940    226
# 14       10955       England                 Harry Kane    2.621982    324
# 15        6196      Colombia                 Yerry Mina    2.449056    325
# 16        5207      Portugal          Cristiano Ronaldo    2.441317    297
# 17        3176       Belgium             Thomas Meunier    2.276687    475
# 18        5170        Russia            Mário Fernandes    2.274088    450
# 19        5474       Croatia               Ivan Perišić    2.070561    454
# 20        5485        France             Raphaël Varane    2.001598    628
# 21        3533   Switzerland            Xherdan Shaqiri    1.949615    450
# 22        3336       England              Harry Maguire    1.933390    829
# 23        5246       Uruguay                Luis Suárez    1.844733    327
# 24        3083   South Korea              Son Heung-Min    1.810799    230
# 25        5692      Colombia     Juan Fernando Quintero    1.782824    374
# 26        5473       Nigeria                 Ahmed Musa    1.776397    162
# 27        5687         Japan               Takashi Inui    1.744770    296
# 28        5674       Senegal               Moussa Wagué    1.701559    168
# 29        5476        France            Benjamin Pavard    1.667134    615
# ..         ...           ...                        ...         ...    ...
# 560       5595    Costa Rica              Johan Venegas   -0.266133    114
# 561       5631        Panama                 Blas Pérez   -0.267232     68
# 563       5213         Spain               Gerard Piqué   -0.275821    674
# 565       5522       Denmark          Nicolai Jørgensen   -0.282520    124
# 566       5536       Denmark             Yussuf Poulsen   -0.291301    228
# 567       5496     Argentina             Cristian Pavón   -0.302398    161
# 570       5242       Morocco            Younès Belhanda   -0.328806    228
# 571       3659     Argentina            Willy Caballero   -0.355115     97
# 572       5188  Saudi Arabia              Hattan Babhir   -0.359462    154
# 574       5481     Australia              Mathew Leckie   -0.402390    219
# 576       5641        Panama       Michael Amir Murillo   -0.406577    182
# 578       3233       England            Raheem Sterling   -0.429548    379
# 579       4447       Denmark         Martin Braithwaite   -0.429842    144
# 581       3054        Brazil                Fernandinho   -0.440532    234
# 582       5501       Iceland  Hörður Björgvin Magnússon   -0.442710    175
# 583       5562       Germany              Thomas Müller   -0.451378    229
# 584       5250         Egypt                Ahmed Fathy   -0.467802    310
# 586       5455       Nigeria       William Troost-Ekong   -0.543371    221
# 587       5573        Mexico              Héctor Moreno   -0.569933    272
# 588       5567        Mexico              Edson Álvarez   -0.620063    337
# 589       5254         Egypt                   Ali Gabr   -0.644969    164
# 590       5668        Poland         Robert Lewandowski   -0.658130    200
# 591       5550   Switzerland                Yann Sommer   -0.686567    211
# 593       5252         Egypt              Marwan Mohsen   -0.766923    125
# 594       5479     Australia                Aziz Behich   -0.832284    365
# 595      11098        Sweden                Marcus Berg   -0.927424    207
# 596       3604        France             Olivier Giroud   -0.944225    324
# 598       3202        Brazil              Gabriel Jesus   -1.005869    273
# 599       4269        Serbia        Aleksandar Mitrović   -1.334005    171
# 601       5685      Colombia             Carlos Sánchez   -1.377752    144
#
#      minutes_played  vaep_rating
# 0               550     0.658297
# 1               602     0.566250
# 2               478     0.637113
# 3               540     0.554803
# 4               312     0.921444
# 5               720     0.397226
# 6               566     0.497577
# 7               563     0.492556
# 8               677     0.397394
# 9               672     0.386160
# 10              289     0.865196
# 11              453     0.540585
# 12              378     0.644002
# 13              355     0.673083
# 14              595     0.396602
# 15              315     0.699730
# 16              381     0.576689
# 17              470     0.435961
# 18              498     0.410980
# 19              646     0.288468
# 20              662     0.272121
# 21              367     0.478107
# 22              675     0.257785
# 23              473     0.351006
# 24              288     0.565875
# 25              309     0.519269
# 26              220     0.726708
# 27              305     0.514850
# 28              208     0.736251
# 29              569     0.263694
# ..              ...          ...
# 560             157    -0.152561
# 561             167    -0.144017
# 563             409    -0.060694
# 565             225    -0.113008
# 566             281    -0.093299
# 567             168    -0.161999
# 570             232    -0.127554
# 571             189    -0.169102
# 572             161    -0.200942
# 574             282    -0.128422
# 576             188    -0.194638
# 578             456    -0.084779
# 579             262    -0.147656
# 581             182    -0.217845
# 582             285    -0.139803
# 583             227    -0.178961
# 584             285    -0.147727
# 586             284    -0.172195
# 587             282    -0.181893
# 588             279    -0.200020
# 589             285    -0.203674
# 590             282    -0.210041
# 591             382    -0.161757
# 593             206    -0.335063
# 594             282    -0.265623
# 595             435    -0.191881
# 596             566    -0.150142
# 598             416    -0.217616
# 599             271    -0.443028
# 601             266    -0.466157
#
# [378 rows x 7 columns]
